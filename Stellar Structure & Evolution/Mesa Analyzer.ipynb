# %%
import mesaPlot as mp

m = mp.MESA()
p = mp.plot()

m.loadHistory()
p.plotHR(m)

# %%
m.loadHistory()
p.plotHistory(m, xaxis="star_age", y1="center_h1", y2="center_he4")
p.plotHistory(m, xaxis="star_age", y1="center_h1", y2="center_n14")
p.plotHistory(m, xaxis="star_age", y1="center_h1", y2="center_c12")
p.plotHistory(m, xaxis="star_age", y1="center_h1", y2="center_o16")
